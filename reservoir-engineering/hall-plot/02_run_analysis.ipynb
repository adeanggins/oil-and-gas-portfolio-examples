# %%
# Cell 1: Imports
from reservoir_diagnostics import ReservoirDiagnostics

# Cell 2: Initialization
# Instantiate the surveillance object for a specific well
well_A = ReservoirDiagnostics(well_name="Well-A (T-Sand)")

# Cell 3: Load Data
# We use the CSVs created in previous steps
well_A.load_production_data('production_data.csv')
well_A.load_injection_data('injection_data.csv')

# Cell 4: Execute Chan Plot
# We can tune the smoothing window directly here
well_A.plot_chan(window_length=7)

# Cell 5: Execute Hall Plot
well_A.plot_hall()
# Out:
# Error: File production_data.csv not found.
# [Well-A (T-Sand)] Injection data loaded successfully.
# Error: Load production data first.
